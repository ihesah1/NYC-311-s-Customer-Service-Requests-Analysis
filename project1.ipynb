# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
df
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM  01/01/2016 12:55:15 AM   NYPD
# 1         32309934  12/31/2015 11:59:44 PM  01/01/2016 01:26:57 AM   NYPD
# 2         32309159  12/31/2015 11:59:29 PM  01/01/2016 04:51:03 AM   NYPD
# 3         32305098  12/31/2015 11:57:46 PM  01/01/2016 07:43:13 AM   NYPD
# 4         32306529  12/31/2015 11:56:58 PM  01/01/2016 03:24:42 AM   NYPD
# ...            ...                     ...                     ...    ...
# 364553    29609918  01/01/2015 12:04:44 AM  01/01/2015 10:22:31 AM   NYPD
# 364554    29608392  01/01/2015 12:04:28 AM  01/01/2015 02:25:02 AM   NYPD
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
for col in df.columns:
    print(col)
# Out:
# Unique Key
# Created Date
# Closed Date
# Agency
# Agency Name
# Complaint Type
# Descriptor
# Location Type
# Incident Zip
# Incident Address
# Street Name
# Cross Street 1
# Cross Street 2
# Intersection Street 1
# Intersection Street 2
# Address Type
# City
# Landmark
# Facility Type
# Status
# Due Date
# Resolution Description
# Resolution Action Updated Date
# Community Board
# Borough
# X Coordinate (State Plane)
# Y Coordinate (State Plane)
# Park Facility Name
# Park Borough
# School Name
# School Number
# School Region
# School Code
# School Phone Number
# School Address
# School City
# School State
# School Zip
# School Not Found
# School or Citywide Complaint
# Vehicle Type
# Taxi Company Borough
# Taxi Pick Up Location
# Bridge Highway Name
# Bridge Highway Direction
# Road Ramp
# Bridge Highway Segment
# Garage Lot Name
# Ferry Direction
# Ferry Terminal Name
# Latitude
# Longitude
# Location

# %%
df.shape
# Out:
# (364558, 53)

# %%
df.isnull().any().sort_values(ascending=False)
# Out:
# Location                           True
# School Region                      True
# X Coordinate (State Plane)         True
# Resolution Action Updated Date     True
# Due Date                           True
# Facility Type                      True
# Landmark                           True
# City                               True
# Address Type                       True
# Intersection Street 2              True
# Intersection Street 1              True
# Cross Street 2                     True
# Cross Street 1                     True
# Street Name                        True
# Incident Address                   True
# Incident Zip                       True
# Location Type                      True
# Descriptor                         True
# Closed Date                        True
# Longitude                          True
# Y Coordinate (State Plane)         True
# School Code                        True
# School Zip                         True
# ...

# %%
##Perform Basic data explatory analysis:
df.isnull().sum().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Closed Date'].isnull().values.any()
# Out:
# True

# %%
df['Closed Date'].isnull().sum()
# Out:
# 2381

# %%
df['Closed Date'].isnull().sort_values(ascending=False)
# Out:
# 181767     True
# 251993     True
# 251927     True
# 251928     True
# 251929     True
#           ...
# 242677    False
# 242678    False
# 242679    False
# 242680    False
# 0         False
# Name: Closed Date, Length: 364558, dtype: bool

# %%
df = df.dropna(axis=0, subset=['Closed Date'])

# %%
df.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                            0
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6496
# Location Type                        130
# Incident Zip                         675
# Incident Address                   51686
# Street Name                        51686
# Cross Street 1                     55331
# Cross Street 2                     55464
# Intersection Street 1             311549
# Intersection Street 2             311673
# Address Type                         929
# City                                 674
# Landmark                          361802
# Facility Type                         18
# Status                                 0
# Due Date                               1
# Resolution Description                 0
# Resolution Action Updated Date        39
# ...

# %%
df['Closed Date']
# Out:
# 0         01/01/2016 12:55:15 AM
# 1         01/01/2016 01:26:57 AM
# 2         01/01/2016 04:51:03 AM
# 3         01/01/2016 07:43:13 AM
# 4         01/01/2016 03:24:42 AM
#                    ...
# 364553    01/01/2015 10:22:31 AM
# 364554    01/01/2015 02:25:02 AM
# 364555    01/01/2015 12:20:33 AM
# 364556    01/01/2015 02:42:22 AM
# 364557    01/01/2015 02:47:50 AM
# Name: Closed Date, Length: 362177, dtype: object

# %%
# Converting the data into datetime format :: 
df["Created Date"]=pd.to_datetime(df['Created Date'])
df["Closed Date"]=pd.to_datetime(df['Closed Date'])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['Closed Date'] 

df['Created Date']
# Out:
# 0        2015-12-31 23:59:45
# 1        2015-12-31 23:59:44
# 2        2015-12-31 23:59:29
# 3        2015-12-31 23:57:46
# 4        2015-12-31 23:56:58
#                  ...
# 364553   2015-01-01 00:04:44
# 364554   2015-01-01 00:04:28
# 364555   2015-01-01 00:01:30
# 364556   2015-01-01 00:01:29
# 364557   2015-01-01 00:00:50
# Name: Created Date, Length: 362177, dtype: datetime64[ns]

# %%
## Convert the calculated date to seconds to get a better representation
df['Request_closing_time']= df["Closed Date"] - df["Created Date"]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Request_closing_time']
# Out:
# 0        0 days 00:55:30
# 1        0 days 01:27:13
# 2        0 days 04:51:34
# 3        0 days 07:45:27
# 4        0 days 03:27:44
#                ...
# 364553   0 days 10:17:47
# 364554   0 days 02:20:34
# 364555   0 days 00:19:03
# 364556   0 days 02:40:53
# 364557   0 days 02:47:00
# Name: Request_closing_time, Length: 362177, dtype: timedelta64[ns]

# %%
Request_Closing_Time=[ ]
for x in (df["Closed Date"]-df["Created Date"]):
    close=x.total_seconds()/60
    Request_Closing_Time.append(close)

# %%
df["Request_Closing_Time"]=Request_Closing_Time

df["Request_Closing_Time"]
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0          55.500000
# 1          87.216667
# 2         291.566667
# 3         465.450000
# 4         207.733333
#              ...
# 364553    617.783333
# 364554    140.566667
# 364555     19.050000
# 364556    160.883333
# 364557    167.000000
# Name: Request_Closing_Time, Length: 362177, dtype: float64

# %%
## View the descriptive statistics for the newly created column
df["Request_Closing_Time"].mean()
# Out:
# 251.88832720833355

# %%
df["Request_Closing_Time"].median()
# Out:
# 160.26666666666668

# %%
#Check the number of null values in the Complaint_Type and City columns
df.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                            0
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          6496
# Location Type                        130
# Incident Zip                         675
# Incident Address                   51686
# Street Name                        51686
# Cross Street 1                     55331
# Cross Street 2                     55464
# Intersection Street 1             311549
# Intersection Street 2             311673
# Address Type                         929
# City                                 674
# Landmark                          361802
# Facility Type                         18
# Status                                 0
# Due Date                               1
# Resolution Description                 0
# Resolution Action Updated Date        39
# ...

# %%
df['Complaint Type'].isnull().sum()
# Out:
# 0

# %%
df['City'].isnull().sum()
# Out:
# 674

# %%
df['City'].fillna('Unknown')
# Out:
# 0                 NEW YORK
# 1                  ASTORIA
# 2                    BRONX
# 3                    BRONX
# 4                 ELMHURST
#                 ...
# 364553           WOODHAVEN
# 364554               BRONX
# 364555            NEW YORK
# 364556               BRONX
# 364557    SOUTH OZONE PARK
# Name: City, Length: 362177, dtype: object

# %%
df.sort_values(['City'],ascending=False)
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 237023    30724960 2015-05-30 00:27:09 2015-05-30 05:36:50   NYPD
# 363808    29622247 2015-01-02 05:58:07 2015-01-02 06:20:09   NYPD
# 233732    30743426 2015-06-01 20:45:40 2015-06-01 23:33:12   NYPD
# 168079    31185073 2015-07-28 09:20:30 2015-07-28 12:26:10   NYPD
# 116513    31517265 2015-09-12 07:24:10 2015-09-12 08:03:36   NYPD
# ...            ...                 ...                 ...    ...
# 361851    29633795 2015-01-04 23:19:28 2015-01-05 10:13:06   NYPD
# 361912    29632589 2015-01-04 21:20:56 2015-01-05 13:46:10   NYPD
# 361975    29633040 2015-01-04 20:04:21 2015-01-05 13:07:15   NYPD
# 362048    29633311 2015-01-04 18:21:17 2015-01-06 08:26:39   NYPD
# 364053    29618280 2015-01-01 19:24:31 2015-01-01 23:44:53   NYPD
#
#                             Agency Name      Complaint Type  \
# 237023  New York City Police Department     Illegal Parking
# ...

# %%
df['City'] = df['City'].fillna('Unknown City')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['City'].isnull().sum()
# Out:
# 0

# %%
#Draw a frequency plot for the complaints in each city
df[['City','Complaint Type']].head()
# Out:
#        City           Complaint Type
# 0  NEW YORK  Noise - Street/Sidewalk
# 1   ASTORIA         Blocked Driveway
# 2     BRONX         Blocked Driveway
# 3     BRONX          Illegal Parking
# 4  ELMHURST          Illegal Parking

# %%
df['City'].value_counts()
# Out:
# BROOKLYN               118849
# NEW YORK                77289
# BRONX                   49166
# STATEN ISLAND           15335
# JAMAICA                  8930
# ASTORIA                  7991
# FLUSHING                 7486
# RIDGEWOOD                6391
# CORONA                   5383
# WOODSIDE                 4357
# EAST ELMHURST            3557
# OZONE PARK               3446
# ELMHURST                 3438
# SOUTH RICHMOND HILL      3431
# MASPETH                  3117
# WOODHAVEN                3102
# LONG ISLAND CITY         3027
# SOUTH OZONE PARK         2668
# FRESH MEADOWS            2453
# RICHMOND HILL            2333
# MIDDLE VILLAGE           2291
# QUEENS VILLAGE           2251
# FOREST HILLS             2122
# JACKSON HEIGHTS          2105
# REGO PARK                1807
# BAYSIDE                  1550
# COLLEGE POINT            1544
# FAR ROCKAWAY             1397
# WHITESTONE               1369
# HOLLIS                   1231
# HOWARD BEACH             1144
# ...

# %%
plt.figure(figsize=(20,10))
df['City'].value_counts().plot(kind='bar',xlabel='City',ylabel='frequency plot for the complaints')
# Out:
# <AxesSubplot:xlabel='City', ylabel='frequency plot for the complaints'>

# %% [markdown]
# ## Create a scatter and hexbin plot of the concentration ofcomplaints across Brooklyn

# %%
df_broklyn = df[df['City']=='BROOKLYN']
df_broklyn.head()
# Out:
#     Unique Key        Created Date         Closed Date Agency  \
# 5     32306554 2015-12-31 23:56:30 2016-01-01 01:50:11   NYPD
# 9     32308391 2015-12-31 23:53:58 2016-01-01 01:17:40   NYPD
# 13    32305074 2015-12-31 23:47:58 2016-01-01 08:18:47   NYPD
# 17    32310273 2015-12-31 23:44:52 2016-01-01 00:36:10   NYPD
# 18    32306617 2015-12-31 23:40:59 2016-01-01 02:37:28   NYPD
#
#                         Agency Name      Complaint Type  \
# 5   New York City Police Department     Illegal Parking
# 9   New York City Police Department    Blocked Driveway
# 13  New York City Police Department     Illegal Parking
# 17  New York City Police Department  Noise - Commercial
# 18  New York City Police Department  Noise - Commercial
#
#                        Descriptor        Location Type  Incident Zip  \
# 5   Posted Parking Sign Violation      Street/Sidewalk       11215.0
# 9                       No Access      Street/Sidewalk       11219.0
# ...

# %%
df_broklyn.shape
# Out:
# (118849, 55)

# %%
#How many complients in BROOKLYN city 
df_broklyn['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             36445
# Illegal Parking              33532
# Noise - Street/Sidewalk      13982
# Noise - Commercial           13855
# Derelict Vehicle              6257
# Noise - Vehicle               5965
# Animal Abuse                  3191
# Noise - Park                  1575
# Traffic                       1258
# Homeless Encampment            948
# Vending                        575
# Noise - House of Worship       389
# Drinking                       291
# Urinating in Public            155
# Bike/Roller/Skate Chronic      124
# Disorderly Youth                79
# Illegal Fireworks               61
# Graffiti                        60
# Posting Advertisement           58
# Panhandling                     49
# Name: Complaint Type, dtype: int64

# %%
df_broklyn.plot(kind= 'scatter' , x='Longitude', y='Latitude',figsize=(15,9)).axis('equal')
# Out:
# (-74.05061403028367, -73.84647934348564, 40.56112685375488, 40.78979838623255)

# %%
df_broklyn.plot(kind= 'hexbin' , x='Longitude', y='Latitude',figsize=(13,8) ,alpha=0.7,
                  gridsize=20,
                  marginals=True,
                  
                  cmap=("jet"),
                  mincnt=5)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
# Plot a bar graph to show the types of complaints

df['Complaint Type'].value_counts().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
#2 Check the frequency of various types of complaints for New York City
df[['City','Complaint Type']]
# Out:
#                     City           Complaint Type
# 0               NEW YORK  Noise - Street/Sidewalk
# 1                ASTORIA         Blocked Driveway
# 2                  BRONX         Blocked Driveway
# 3                  BRONX          Illegal Parking
# 4               ELMHURST          Illegal Parking
# ...                  ...                      ...
# 364553         WOODHAVEN          Illegal Parking
# 364554             BRONX          Noise - Vehicle
# 364555          NEW YORK  Noise - Street/Sidewalk
# 364556             BRONX         Blocked Driveway
# 364557  SOUTH OZONE PARK         Blocked Driveway
#
# [362177 rows x 2 columns]

# %%
# Check the frequency of various types of complaints for New York City
df_ny = df[df['City']=='NEW YORK']

# %%
# df_ny = df['Complaint Type']

# %%
df_ny
# Out:
#         Unique Key        Created Date         Closed Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:15   NYPD
# 6         32306559 2015-12-31 23:55:32 2016-01-01 01:53:54   NYPD
# 19        32308195 2015-12-31 23:40:55 2016-01-01 00:28:31   NYPD
# 23        32308765 2015-12-31 23:32:46 2016-01-01 00:25:21   NYPD
# 26        32305916 2015-12-31 23:26:41 2015-12-31 23:53:31   NYPD
# ...            ...                 ...                 ...    ...
# 364542    29607990 2015-01-01 00:19:20 2015-01-01 03:17:10   NYPD
# 364543    29609631 2015-01-01 00:18:49 2015-01-01 03:17:11   NYPD
# 364547    29608295 2015-01-01 00:15:33 2015-01-01 00:56:37   NYPD
# 364552    29610051 2015-01-01 00:05:05 2015-01-01 01:22:10   NYPD
# 364555    29607589 2015-01-01 00:01:30 2015-01-01 00:20:33   NYPD
#
#                             Agency Name            Complaint Type  \
# 0       New York City Police Department   Noise - Street/Sidewalk
# ...

# %%
# Find the top 10 complaint types
# df_ny = df['Complaint Type']
df_ny['Complaint Type'].value_counts().head(10).plot(kind='bar',title='top 10 complaint types in new york city' ,figsize=(14,9))
# Out:
# <AxesSubplot:title={'center':'top 10 complaint types in new york city'}>

# %%
#Display the various types of complaints in each city
cty_com = df.groupby(['City','Complaint Type']).size()
#Create a DataFrame, df_new, which contains cities as columns and complaint types in rows
new_df = pd.DataFrame({'Count':cty_com}).reset_index()
new_df.head(20)
# Out:
#        City             Complaint Type  Count
# 0   ARVERNE               Animal Abuse     46
# 1   ARVERNE           Blocked Driveway     50
# 2   ARVERNE           Derelict Vehicle     32
# 3   ARVERNE           Disorderly Youth      2
# 4   ARVERNE                   Drinking      1
# 5   ARVERNE                   Graffiti      1
# 6   ARVERNE        Homeless Encampment      4
# 7   ARVERNE            Illegal Parking     62
# 8   ARVERNE         Noise - Commercial      2
# 9   ARVERNE   Noise - House of Worship     14
# 10  ARVERNE               Noise - Park      2
# 11  ARVERNE    Noise - Street/Sidewalk     29
# 12  ARVERNE            Noise - Vehicle     10
# 13  ARVERNE                Panhandling      1
# 14  ARVERNE                    Traffic      1
# 15  ARVERNE        Urinating in Public      1
# 16  ARVERNE                    Vending      1
# 17  ASTORIA               Animal Abuse    170
# 18  ASTORIA  Bike/Roller/Skate Chronic     16
# ...

# %%
#Draw another chart that shows the types of complaints in each city in a single chart, where different colors show the different types of complaints
color = ['lightcoral', 'darkorange', 'olive', 'teal', 'violet', 'skyblue']
df[['Complaint Type','City']].value_counts().head(30).plot(kind = 'bar',figsize=(14,7),color=color)

plt.xlabel("types of complaints")
plt.ylabel(" City")
# Out:
# Text(0, 0.5, ' City')

# %%
# Sort the complaint types based on the average Request_Closing_Time grouping them for different locations
s = sort_values(ascending=df['Request_Closing_Time'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-0d392bb20ffd> in <module>
#       1 # Sort the complaint types based on the average Request_Closing_Time grouping them for different locations
# ----> 2 s = sort_values(ascending=df['Request_Closing_Time'])
#
# NameError: name 'sort_values' is not defined

# %%
# Sort the complaint types based on the average Request_Closing_Time grouping them for different locations

# %%
group_city_complient = df.groupby(['City','Complaint Type'])['Request_Closing_Time'].mean().unstack(level=1)
group_city_complient = group_city_complient.T
group_city_complient
# Out:
# City                          ARVERNE     ASTORIA     Astoria     BAYSIDE  \
# Complaint Type
# Agency Issues                     NaN         NaN         NaN         NaN
# Animal Abuse               139.986594  286.781373         NaN  186.725786
# Animal in a Park                  NaN         NaN         NaN         NaN
# Bike/Roller/Skate Chronic         NaN  111.979167         NaN         NaN
# Blocked Driveway           138.647333  275.265575  274.881027  155.765759
# Derelict Vehicle           189.900000  540.776643  417.207143  204.360462
# Disorderly Youth           215.475000  161.896667         NaN  155.641667
# Drinking                    14.316667  258.637984         NaN  114.133333
# Graffiti                    91.800000  845.704167         NaN  273.022222
# Homeless Encampment        109.020833  295.071875         NaN  172.375000
# Illegal Fireworks                 NaN  166.320833         NaN         NaN
# ...

# %%
df['Request_Closing_Time'] = df['Closed Date'] - df['Created Date']

df['Request_Closing_Hours'] = df['Request_Closing_Time'].astype('timedelta64[h]')+1 
df[['Request_Closing_Time','Request_Closing_Hours']].head(10)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Request_Closing_Time  Request_Closing_Hours
# 0      0 days 00:55:30                    1.0
# 1      0 days 01:27:13                    2.0
# ...

# %%
# Visualize the average of Request_Closing_Time 

a = df.groupby(['Complaint Type'])[['Request_Closing_Hours']].mean()
a.plot(kind='bar',title='Avg Response Time of Complaints', xlabel='Complaint_Type', ylabel='Average Response Time')
plt.show()
